# %%
import pandas as pd
data = pd.read_csv("../data/interm/game.csv")
print(data.columns)
# Out:
# Index(['participantId', 'teamId', 'championId', 'spell1Id', 'spell2Id',
#        'stats.participantId', 'stats.win', 'stats.item0', 'stats.item1',
#        'stats.item2',
#        ...
#        'tournament', 'gameDate', 'summonerName', 'teamName', 'soloKills',
#        'soloDeaths', 'role', 'kda', 'kp', 'championName'],
#       dtype='object', length=129)

# %%
data['stats.win'] = data['stats.win'].astype(int)
data.head()
# Out:
#    participantId teamId  championId  spell1Id  spell2Id  stats.participantId  \
# 0              1   Blue         150         4        12                    1
# 1              2   Blue         163         4        11                    2
# 2              3   Blue         112         4        12                    3
# 3              4   Blue         145         7         4                    4
# 4              5   Blue         201         3         4                    5
#
#    stats.win  stats.item0  stats.item1  stats.item2  ...         tournament  \
# 0          0         6631         3111         2055  ...  Leviathan Masters
# 1          0         3157         6653         2055  ...  Leviathan Masters
# 2          0         3040         6653         3157  ...  Leviathan Masters
# 3          0         3046         2420         6672  ...  Leviathan Masters
# 4          0         3190         3857         2055  ...  Leviathan Masters
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(40,40))
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     350     try:
# --> 351         dt = signed_to_unsigned[dt.type]
#     352     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-570e207d9289> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pyplot as plt
# ----> 3 data.hist(bins=50, figsize=(40,40))
#
# ...

# %%
import plotly.express as px
championData = data.groupby("championName").mean()
fig1 = px.scatter_matrix(
        championData, dimensions=['stats.win'], color="championName")
fig1.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-0c21a5f7e610> in <module>
#       1 import plotly.express as px
#       2 championData = data.groupby("championName").mean()
# ----> 3 fig1 = px.scatter_matrix(
#       4         championData, dimensions=['stats.win'], color="championName")
#       5 fig1.show()
#
# ~/.local/lib/python3.8/site-packages/plotly/express/_chart_types.py in scatter_matrix(data_frame, dimensions, color, symbol, size, hover_name, hover_data, custom_data, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, title, template, width, height)
#    1269     other.
#    1270     """
# -> 1271     return make_figure(
#    1272         args=locals(), constructor=go.Splom, layout_patch=dict(dragmode="select")
# ...

# %%
corr_matrix = data.corr()

# %%
corr_matrix['stats.win'].sort_values(ascending=False)
# Out:
# stats.win                     1.000000
# kda                           0.718624
# stats.assists                 0.606863
# stats.firstInhibitorAssist    0.533037
# stats.turretKills             0.482832
#                                 ...
# stats.playerScore8                 NaN
# stats.playerScore9                 NaN
# queueId                            NaN
# mapId                              NaN
# seasonId                           NaN
# Name: stats.win, Length: 118, dtype: float64

# %%
corr_matrix['stats.win'].sort_values(ascending=True)
# Out:
# stats.deaths               -0.599538
# stats.magicalDamageTaken   -0.218350
# soloDeaths                 -0.145420
# stats.item1                -0.145234
# stats.trueDamageTaken      -0.125839
#                               ...
# stats.playerScore8               NaN
# stats.playerScore9               NaN
# queueId                          NaN
# mapId                            NaN
# seasonId                         NaN
# Name: stats.win, Length: 118, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes = ['stats.win','kda', 'stats.assists','stats.turretKills']

# %%
scatter_matrix(data[attributes], figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='stats.win', ylabel='stats.win'>,
#         <AxesSubplot:xlabel='kda', ylabel='stats.win'>,
#         <AxesSubplot:xlabel='stats.assists', ylabel='stats.win'>,
#         <AxesSubplot:xlabel='stats.turretKills', ylabel='stats.win'>],
#        [<AxesSubplot:xlabel='stats.win', ylabel='kda'>,
#         <AxesSubplot:xlabel='kda', ylabel='kda'>,
#         <AxesSubplot:xlabel='stats.assists', ylabel='kda'>,
#         <AxesSubplot:xlabel='stats.turretKills', ylabel='kda'>],
#        [<AxesSubplot:xlabel='stats.win', ylabel='stats.assists'>,
#         <AxesSubplot:xlabel='kda', ylabel='stats.assists'>,
#         <AxesSubplot:xlabel='stats.assists', ylabel='stats.assists'>,
#         <AxesSubplot:xlabel='stats.turretKills', ylabel='stats.assists'>],
#        [<AxesSubplot:xlabel='stats.win', ylabel='stats.turretKills'>,
#         <AxesSubplot:xlabel='kda', ylabel='stats.turretKills'>,
#         <AxesSubplot:xlabel='stats.assists', ylabel='stats.turretKills'>,
# ...
